# %%
import numpy as np,pandas as pd
import matplotlib.pyplot as plt,seaborn as sns
from mlxtend.preprocessing import TransactionEncoder

# %%
dataset = [
    ['potatoes', 'banana', 'potatoes', 'curry', 'curry'],
    ['curry', 'burger', 'banana', 'pasta', 'sandwich'],
    ['potatoes', 'beef', 'fish', 'banana', 'fish'],
    ['rice', 'bread', 'noodles', 'potatoes', 'banana'],
    ['curry', 'banana', 'stir-fry', 'curry', 'fish']
]

# %%
te = TransactionEncoder()
te_ary = te.fit_transform(dataset)
df = pd.DataFrame(te_ary,columns=te.columns_)
df
# Out:
#    banana   beef  bread  burger  curry   fish  noodles  pasta  potatoes  \
# 0    True  False  False   False   True  False    False  False      True
# 1    True  False  False    True   True  False    False   True     False
# 2    True   True  False   False  False   True    False  False      True
# 3    True  False   True   False  False  False     True  False      True
# 4    True  False  False   False   True   True    False  False     False
#
#     rice  sandwich  stir-fry
# 0  False     False     False
# 1  False      True     False
# 2  False     False     False
# 3   True     False     False
# 4  False     False      True

# %%
from mlxtend.frequent_patterns import fpgrowth
fpgrowth(df,min_support=0.6)
# Out:
#    support itemsets
# 0      1.0      (0)
# 1      0.6      (8)
# 2      0.6      (4)
# 3      0.6   (8, 0)
# 4      0.6   (0, 4)

# %%
fpgrowth(df,min_support=0.6,use_colnames=True)
# Out:
#    support            itemsets
# 0      1.0            (banana)
# 1      0.6          (potatoes)
# 2      0.6             (curry)
# 3      0.6  (potatoes, banana)
# 4      0.6     (curry, banana)
